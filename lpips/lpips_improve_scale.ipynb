# %% [markdown]
# <a href="https://colab.research.google.com/github/duskvirkus/colab-ml-art/blob/main/lpips/lpips_improve_scale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-feece39b-20d9-7788-8378-935403fad7f5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%writefile requirements.txt
# numpy>=1.7.0
# imutils==0.5.2
# opencv-python>=4.1.0.25
# scipy
# lpips
# torch==1.7.1
# torchvision==0.8.2
# Out:
# Writing requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: imutils==0.5.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (0.5.2)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (4.1.2.30)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: lpips in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (0.1.3)
# Requirement already satisfied: torch==1.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (1.7.1)
# Requirement already satisfied: torchvision==0.8.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (0.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1->-r requirements.txt (line 6)) (3.7.4.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.8.2->-r requirements.txt (line 7)) (7.1.2)

# %%
# %%writefile lpips-improve-scale.py

import argparse
import queue
import lpips
import torch
import os
import cv2
import numpy as np
import _thread

def saveImage(img,path,filename):
	if(args.file_extension == "png"):
		new_file = os.path.splitext(filename)[0] + ".png"
		cv2.imwrite(os.path.join(path, new_file), img, [cv2.IMWRITE_PNG_COMPRESSION, 0])
	elif(args.file_extension == "jpg"):
		new_file = os.path.splitext(filename)[0] + ".jpg"
		cv2.imwrite(os.path.join(path, new_file), img, [cv2.IMWRITE_JPEG_QUALITY, 90])

def parse_args():
    desc = "Tools to crop unnecessary space from outside of images" 
    parser = argparse.ArgumentParser(description=desc)

    parser.add_argument('-i','--input_folder', type=str,
        default='./input/',
        help='Directory path to the inputs folder. (default: %(default)s)')

    parser.add_argument('-c', '--compare_folder', type=str,
        default='./compare/',
        help='Directory path to the compare folder. (default: %(default)s)')

    parser.add_argument('-o','--output_folder', type=str,
        default='./output/',
        help='Directory path to the outputs folder. (default: %(default)s)')

    parser.add_argument('--file_extension', type=str,
        default='png',
        help='file extension ["png","jpg"] (default: %(default)s)')

    parser.add_argument('--verbose', action='store_true',
        help='Print progress to console.')

    parser.add_argument('--use_gpu', action='store_true',
        help='Use GPU for lpips.')

    parser.add_argument('-j' '--jobs', type=int,
        default=1,
        help='The number of threads to use. (default: %(default)s)')

    args = parser.parse_args()
    return args

def threadRunner(threadName):
    while(not q.empty()):
        filename = q.get()
        optimize_image(threadName, filename)

def optimize_image(threadName, filename):
    file_path = os.path.join(rootDir, filename)
    if(args.verbose): print('(%s) processing\t- file %s (full path: %s)' % (threadName, filename, file_path))
            
    img = lpips.load_image(file_path)
    # print(type(img))

    r,g,b = cv2.split(img)
    img_bgr = cv2.merge([b,g,r])

    scaled_images = []
    for i in np.arange(0.8, 1.3, 0.1):
        scaled_images.append(scale_image(img_bgr, i))
        # saveImage(scaled_images[-1],args.output_folder,str(i) + filename)


    # for i in range(len(scaled_images)):

    tensors = []
    for i in range(len(scaled_images)):
        b, g, r = cv2.split(scaled_images[i])
        tensor = lpips.im2tensor(cv2.merge([r, g, b]))
        if args.use_gpu:
            tensor = tensor.cuda()
        tensors.append(tensor)

    values = []
    for i in range(len(tensors)):
        val = 0.0
        for j in range(len(compare_imgs)):
            # print(tensors[i], compare_imgs[j])

            img0 = tensors[i]
            img1 = compare_imgs[j]

            # if(args.use_gpu):
            #     img0 = img0.cuda()
            #     img1 = img1.cuda()

            val += loss_fn_vgg.forward(img0, img1).detach().item()


        values.append(val/len(compare_imgs))

    maxIndex = 0
    maxVal = 0.0
    for i in range(len(values)):
        if (values[i] > maxVal):
            maxIndex = i
            maxVal = values[i]

    if args.verbose:
        print(values)
        print('saving index %d' % maxIndex)

    saveImage(scaled_images[maxIndex],args.output_folder,filename)




    # if hasattr(img, 'copy'):
    #     processImage(img,os.path.splitext(filename)[0])

def scale_image(image: np.ndarray, scale: float) -> np.ndarray:
        if scale == 0:
            return image.copy()
        out = image.copy()
        start_shape = out.shape
        dim = (int(out.shape[1] * scale), int(out.shape[0] * scale))
        if scale > 1:
            out = cv2.resize(out, dim, interpolation=cv2.INTER_AREA)
            x_crop = (dim[0] - start_shape[1]) // 2
            y_crop = (dim[1] - start_shape[0]) // 2
            out = out[y_crop:dim[1] - y_crop, x_crop:dim[0] - x_crop]
        else:
            out = cv2.resize(out, dim, interpolation=cv2.INTER_AREA)

            pad_x = (start_shape[1] - dim[0]) // 2
            pad_y = (start_shape[0] - dim[1]) // 2

            in_img_h, in_img_w, channels = out.shape
            out_img_h = in_img_h + (pad_y * 2)
            out_img_w = in_img_w + (pad_x * 2)
            mask = np.zeros((out_img_h, out_img_w, 1), np.uint8)
            fill_color = (255, 255, 255)
            out_img = cv2.copyMakeBorder(out, pad_y, pad_y, pad_x, pad_x, cv2.BORDER_CONSTANT, value=fill_color)
            mask = cv2.rectangle(mask, (0, 0), (pad_x - 1, out_img_h - 1), (255), -1)
            mask = cv2.rectangle(mask, (0, 0), (out_img_w - 1, pad_y - 1), (255), -1)
            mask = cv2.rectangle(mask, (0, out_img_h - pad_y), (out_img_w - 1, out_img_h - 1), (255), -1)
            mask = cv2.rectangle(mask, (out_img_w - pad_x, 0), (out_img_w - 1, out_img_h - 1), (255), -1)

            out = cv2.inpaint(out_img, mask, 3, cv2.INPAINT_TELEA)

        if out.shape[1] != 1024 or out.shape[0] != 1024:
            out = cv2.resize(out, (1024, 1024), interpolation=cv2.INTER_AREA)

        return out

def main():
    global args
    global q
    global rootDir
    global compare_imgs
    global loss_fn_vgg
    args = parse_args()
    q = queue.Queue()
    compare_imgs = []
    loss_fn_vgg = lpips.LPIPS(net='vgg', version=0.1)

    if(args.use_gpu):
	    loss_fn_vgg.cuda()

    if os.path.isdir(args.input_folder):
        print("Processing folder: " + args.input_folder)
    else:
        print("Not a working input_folder path: " + args.input_folder)
        return

    if os.path.isdir(args.compare_folder):
        print("Compare folder: " + args.compare_folder)
    else:
        print("Not a working compare_folder path: " + args.compare_folder)
        return

    os.makedirs(args.output_folder, exist_ok=True)

    for root, subdirs, files in os.walk(args.compare_folder):
        if(args.verbose): print('--\nroot = ' + root)

        for subdir in subdirs:
            if(args.verbose): print('\t- subdirectory ' + subdir)

        for filename in files:
            # add files to queue
            file_path = os.path.join(root, filename)
            img = lpips.load_image(file_path)
            # print(img)
            tensor = lpips.im2tensor(img)
            if args.use_gpu:
                tensor = tensor.cuda()
            compare_imgs.append(tensor)
            

    for root, subdirs, files in os.walk(args.input_folder):
        if(args.verbose): print('--\nroot = ' + root)
        rootDir = root

        for subdir in subdirs:
            if(args.verbose): print('\t- subdirectory ' + subdir)

        for filename in files:
            # add files to queue
            q.put(filename)

    # start threads
    for i in range(args.j__jobs):
        try:
            threadName = 'thread-' + str(i)
            if(args.verbose): print('starting thread %s' % (threadName))
            _thread.start_new_thread(threadRunner, (threadName,))
        except:
            print("error! unable to start thread.")

    while (not q.empty()):
        pass


if __name__ == "__main__":
    main()
# Out:
# Writing lpips-improve-scale.py

# %%
# !python lpips-improve-scale.py --help

# %%
input_folder = '/content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024'
compare_folder = '/content/drive/MyDrive/dataset-creation/treeflowers/compare-1024'
output_folder = '/content/drive/MyDrive/dataset-creation/treeflowers/out'

# %%
# !python lpips-improve-scale.py -i {input_folder} -c {compare_folder} -o {output_folder} --verbose --use_gpu
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.7/dist-packages/lpips/weights/v0.1/vgg.pth
# Processing folder: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024
# Compare folder: /content/drive/MyDrive/dataset-creation/treeflowers/compare-1024
# --
# root = /content/drive/MyDrive/dataset-creation/treeflowers/compare-1024
# --
# root = /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024
# starting thread thread-0
# (thread-0) processing	- file IMG_6818.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6818.png)
# [0.6323416630427042, 0.6393341024716696, 0.6376071770985922, 0.6389348904291788, 0.6370251774787903]
# saving index 1
# (thread-0) processing	- file IMG_6803.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6803.png)
# [0.673864483833313, 0.6750639081001282, 0.6842909455299377, 0.6581073005994161, 0.6509732802708944]
# saving index 2
# (thread-0) processing	- file IMG_6801.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6801.png)
# [0.6923735936482748, 0.7024563153584799, 0.7114983995755514, 0.7019833922386169, 0.6981746753056844]
# saving index 2
# (thread-0) processing	- file IMG_6800.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6800.png)
# [0.6968986392021179, 0.7040204405784607, 0.7135541439056396, 0.702727735042572, 0.7047668099403381]
# saving index 2
# (thread-0) processing	- file IMG_6802.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6802.png)
# [0.6902775565783182, 0.6996707320213318, 0.69800998767217, 0.6959851980209351, 0.6942019065221151]
# saving index 1
# (thread-0) processing	- file IMG_6804.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6804.png)
# [0.685583213965098, 0.6899082859357198, 0.7191242575645447, 0.6932017008463541, 0.6925126314163208]
# saving index 2
# (thread-0) processing	- file IMG_6839.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6839.png)
# [0.6554171840349833, 0.6649994254112244, 0.657320241133372, 0.6640247503916422, 0.6678951978683472]
# saving index 4
# (thread-0) processing	- file IMG_6828.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6828.png)
# [0.654478391011556, 0.6693582137425741, 0.6632754604021708, 0.6737800637880961, 0.6780648032824198]
# saving index 4
# (thread-0) processing	- file IMG_6829.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6829.png)
# [0.6697598894437155, 0.6798169811566671, 0.674220860004425, 0.6742829084396362, 0.6734547217686971]
# saving index 1
# (thread-0) processing	- file IMG_6834.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6834.png)
# [0.6365450620651245, 0.643478532632192, 0.6413035988807678, 0.6395852168401083, 0.6357499957084656]
# saving index 1
# (thread-0) processing	- file IMG_6833.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6833.png)
# [0.6645046671231588, 0.67686661084493, 0.6706987222035726, 0.6714653174082438, 0.6741694410641988]
# saving index 1
# (thread-0) processing	- file IMG_6830.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6830.png)
# [0.635739286740621, 0.6438351273536682, 0.6358926296234131, 0.6403699119885763, 0.6424430807431539]
# saving index 1
# (thread-0) processing	- file IMG_6836.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6836.png)
# [0.6178443431854248, 0.6255655288696289, 0.6285550196965536, 0.6225614249706268, 0.6162959535916647]
# saving index 2
# (thread-0) processing	- file IMG_6822.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6822.png)
# [0.6615055004755656, 0.6674944361050924, 0.6569275657335917, 0.6654065251350403, 0.6646056969960531]
# saving index 1
# (thread-0) processing	- file IMG_6827.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6827.png)
# [0.6181294818719228, 0.6251516242822012, 0.6104663610458374, 0.6171417633692423, 0.6210184395313263]
# saving index 1
# (thread-0) processing	- file IMG_6831.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6831.png)
# [0.6215403576691946, 0.6233601172765096, 0.618536909421285, 0.6231239338715872, 0.6226435005664825]
# saving index 1
# (thread-0) processing	- file IMG_6823.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6823.png)
# [0.663503110408783, 0.676800270875295, 0.6662187178929647, 0.6752081314722697, 0.6733325918515524]
# saving index 1
# (thread-0) processing	- file IMG_6825.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6825.png)
# [0.645775039990743, 0.6520302494366964, 0.645044724146525, 0.6491830348968506, 0.6489459276199341]
# saving index 1
# (thread-0) processing	- file IMG_6824.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6824.png)
# [0.6602194507916769, 0.6778660615285238, 0.6766957839330038, 0.681669294834137, 0.6813546617825826]
# saving index 3
# (thread-0) processing	- file IMG_6820.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6820.png)
# [0.654869814713796, 0.6705635984738668, 0.6723686059316, 0.6828688979148865, 0.6847469409306844]
# saving index 4
# (thread-0) processing	- file IMG_6821.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6821.png)
# [0.6621608138084412, 0.6717168688774109, 0.6702772776285807, 0.6782257358233134, 0.677971621354421]
# saving index 3
# (thread-0) processing	- file IMG_6808.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6808.png)
# [0.6904939611752828, 0.696299691994985, 0.6977169513702393, 0.6890343030293783, 0.6885822216669718]
# saving index 2
# (thread-0) processing	- file IMG_6819.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6819.png)
# [0.6628594398498535, 0.6759128570556641, 0.6800734400749207, 0.6850999593734741, 0.6877389152844747]
# saving index 4
# (thread-0) processing	- file IMG_6817.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6817.png)
# [0.6769722104072571, 0.6867331465085348, 0.685951034228007, 0.687705934047699, 0.6858638525009155]
# saving index 3
# (thread-0) processing	- file IMG_6854.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6854.png)
# [0.6696276466051737, 0.6813331842422485, 0.6798975268999735, 0.6821501851081848, 0.6760502258936564]
# saving index 3
# (thread-0) processing	- file IMG_6849.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6849.png)
# [0.634128580490748, 0.638801117738088, 0.6290101806322733, 0.6299221714337667, 0.6229256292184194]
# saving index 1
# (thread-0) processing	- file IMG_6853.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6853.png)
# [0.6693549752235413, 0.6743820707003275, 0.6685468157132467, 0.668169895807902, 0.666248102982839]
# saving index 1
# (thread-0) processing	- file IMG_6851.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6851.png)
# [0.6303114295005798, 0.6344724694887797, 0.6309102376302084, 0.6326991319656372, 0.6373430093129476]
# saving index 4
# (thread-0) processing	- file IMG_6852.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6852.png)
# [0.66434246301651, 0.6723238428433737, 0.6667490204175314, 0.6703594128290812, 0.6690140167872111]
# saving index 1
# (thread-0) processing	- file IMG_6847.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6847.png)
# [0.6392540136973063, 0.646254817644755, 0.6471437613169352, 0.6500807007153829, 0.651192327340444]
# saving index 4
# (thread-0) processing	- file IMG_6855.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6855.png)
# [0.6755037307739258, 0.6867942611376444, 0.6750746568044027, 0.6777340769767761, 0.6743311285972595]
# saving index 1
# (thread-0) processing	- file IMG_6845.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6845.png)
# [0.6520582040150961, 0.6638424396514893, 0.6656467119852701, 0.6676730116208395, 0.6678389112154642]
# saving index 4
# (thread-0) processing	- file IMG_6846.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6846.png)
# [0.6618853807449341, 0.6743383208910624, 0.6676303148269653, 0.6756915251413981, 0.6762139598528544]
# saving index 4
# (thread-0) processing	- file IMG_6841.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6841.png)
# [0.6342130502065023, 0.6433370113372803, 0.6353148023287455, 0.6429404815038046, 0.6473581989606222]
# saving index 4
# (thread-0) processing	- file IMG_6848.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6848.png)
# [0.6362417141596476, 0.647157351175944, 0.6416068275769552, 0.6504526138305664, 0.6537260413169861]
# saving index 4
# (thread-0) processing	- file IMG_6840.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6840.png)
# [0.6392172574996948, 0.6449445883433024, 0.6301898161570231, 0.6303996046384176, 0.6250960826873779]
# saving index 1
# (thread-0) processing	- file IMG_6842.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6842.png)
# [0.6281221508979797, 0.6391303539276123, 0.633322020371755, 0.6462353269259135, 0.6485023498535156]
# saving index 4
# (thread-0) processing	- file IMG_6843.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6843.png)
# [0.6551813284556071, 0.6650367180506388, 0.656100352605184, 0.6533608039220175, 0.6502267122268677]
# saving index 1
# (thread-0) processing	- file IMG_6837.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6837.png)
# [0.6346511542797089, 0.6432014107704163, 0.641882598400116, 0.64531542857488, 0.6438878774642944]
# saving index 3
# (thread-0) processing	- file IMG_6838.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6838.png)
# [0.6606713533401489, 0.6683645049730936, 0.6634568969408671, 0.6640744010607401, 0.6623213291168213]
# saving index 1
# (thread-0) processing	- file IMG_6835.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6835.png)
# [0.651009738445282, 0.6589828928311666, 0.653858502705892, 0.6513097286224365, 0.6478108763694763]
# saving index 1
# (thread-0) processing	- file IMG_6886.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6886.png)
# [0.6713879505793253, 0.6869749228159586, 0.6834839781125387, 0.6926554838816324, 0.6900991797447205]
# saving index 3
# (thread-0) processing	- file IMG_6880.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6880.png)
# [0.681408166885376, 0.6890683174133301, 0.6805873115857443, 0.6821677486101786, 0.6760360598564148]
# saving index 1
# (thread-0) processing	- file IMG_6881.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6881.png)
# [0.6534252365430196, 0.6600231925646464, 0.6501641074816386, 0.6520291368166605, 0.647726813952128]
# saving index 1
# (thread-0) processing	- file IMG_6879.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6879.png)
# [0.5936699708302816, 0.5852663417657217, 0.4950442396123738, 0.5731342534224192, 0.5871524810791016]
# saving index 0
# (thread-0) processing	- file IMG_6873.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6873.png)
# [0.7087124983469645, 0.7201626300811768, 0.7249282201131185, 0.7240562438964844, 0.7217204173405966]
# saving index 2
# (thread-0) processing	- file IMG_6875.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6875.png)
# [0.6794515450795492, 0.6859279076258341, 0.6761541167894999, 0.6790861487388611, 0.6763551831245422]
# saving index 1
# (thread-0) processing	- file IMG_6876.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6876.png)
# [0.6752036015192667, 0.6897579431533813, 0.6883144974708557, 0.6947488784790039, 0.6964263518651327]
# saving index 4
# (thread-0) processing	- file IMG_6878.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6878.png)
# [0.6139901081720988, 0.613044818242391, 0.6079116861025492, 0.6015575130780538, 0.5985946754614512]
# saving index 0
# (thread-0) processing	- file IMG_6872.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6872.png)
# [0.6616174777348837, 0.677661677201589, 0.6782150268554688, 0.6746501723925272, 0.6727184851964315]
# saving index 2
# (thread-0) processing	- file IMG_6874.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6874.png)
# [0.6745058298110962, 0.685575803120931, 0.6760136087735494, 0.6843647559483846, 0.6833418210347494]
# saving index 1
# (thread-0) processing	- file IMG_6871.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6871.png)
# [0.6517021059989929, 0.6642447908719381, 0.6600017746289571, 0.6610438823699951, 0.6568275491396586]
# saving index 1
# (thread-0) processing	- file IMG_6862.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6862.png)
# [0.678447941939036, 0.6962551673253378, 0.6961365938186646, 0.6987467209498087, 0.691015362739563]
# saving index 3
# (thread-0) processing	- file IMG_6863.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6863.png)
# [0.6775103807449341, 0.688753585020701, 0.6906558076540629, 0.6958868900934855, 0.6955530643463135]
# saving index 3
# (thread-0) processing	- file IMG_6866.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6866.png)
# [0.6898045341173807, 0.6935617327690125, 0.6930018266042074, 0.6761325796445211, 0.6668944160143534]
# saving index 1
# (thread-0) processing	- file IMG_6869.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6869.png)
# [0.6765631635983785, 0.6775397459665934, 0.6743948062260946, 0.6611768205960592, 0.6570653120676676]
# saving index 1
# (thread-0) processing	- file IMG_6859.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6859.png)
# [0.6481061577796936, 0.656981905301412, 0.6517372528711954, 0.6531896193822225, 0.652904192606608]
# saving index 1
# (thread-0) processing	- file IMG_6860.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6860.png)
# [0.6710866093635559, 0.6825546820958456, 0.6835164427757263, 0.6809327602386475, 0.6783263285954794]
# saving index 2
# (thread-0) processing	- file IMG_6858.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6858.png)
# [0.6664336919784546, 0.679430882136027, 0.6730348070462545, 0.6764776508013407, 0.6719720760981241]
# saving index 1
# (thread-0) processing	- file IMG_6856.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6856.png)
# [0.684831976890564, 0.6985450387001038, 0.6789104541142782, 0.6891063849131266, 0.6823816696802775]
# saving index 1
# (thread-0) processing	- file IMG_6857.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6857.png)
# [0.6827737291653951, 0.6968578696250916, 0.6816393931706747, 0.6896459261576334, 0.6864631374677023]
# saving index 1
# (thread-0) processing	- file IMG_6901.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6901.png)
# [0.6190451979637146, 0.617133359114329, 0.6044034759203593, 0.6002337535222372, 0.5975635846455892]
# saving index 0
# (thread-0) processing	- file IMG_6895.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6895.png)
# [0.6730695764223734, 0.6828875740369161, 0.6717339555422465, 0.680036743481954, 0.6808770298957825]
# saving index 1
# (thread-0) processing	- file IMG_6898.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6898.png)
# [0.6493641138076782, 0.6553034782409668, 0.6503570675849915, 0.6524251103401184, 0.652571459611257]
# saving index 1
# (thread-0) processing	- file IMG_6902.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6902.png)
# [0.667772650718689, 0.6756684978802999, 0.6690350373586019, 0.6667357285817465, 0.6612219413121542]
# saving index 1
# (thread-0) processing	- file IMG_6899.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6899.png)
# [0.6710120836893717, 0.682026207447052, 0.676384170850118, 0.6775428851445516, 0.6724540193875631]
# saving index 1
# (thread-0) processing	- file IMG_6892.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6892.png)
# [0.6725828051567078, 0.6851766506830851, 0.6713393330574036, 0.6775764226913452, 0.6716416478157043]
# saving index 1
# (thread-0) processing	- file IMG_6890.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6890.png)
# [0.6318146586418152, 0.6370574633280436, 0.6315876046816508, 0.6331351399421692, 0.6335458556811014]
# saving index 1
# (thread-0) processing	- file IMG_6893.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6893.png)
# [0.6601990660031637, 0.6740936636924744, 0.674304723739624, 0.6810011267662048, 0.6816697518030802]
# saving index 4
# (thread-0) processing	- file IMG_6891.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6891.png)
# [0.6341557701428732, 0.6387988924980164, 0.6306274731953939, 0.6324964364369711, 0.6300661961237589]
# saving index 1
# (thread-0) processing	- file IMG_6887.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6887.png)
# [0.6815627415974935, 0.6988732616106669, 0.6974725723266602, 0.7088546752929688, 0.7123494148254395]
# saving index 4
# (thread-0) processing	- file IMG_6888.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6888.png)
# [0.6661465167999268, 0.6762232780456543, 0.6769276857376099, 0.6818410754203796, 0.681827982266744]
# saving index 3
# (thread-0) processing	- file IMG_6889.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6889.png)
# [0.6725288033485413, 0.6824443141619364, 0.6898758212725321, 0.6875338951746622, 0.6873673399289449]
# saving index 2
# (thread-0) processing	- file IMG_6885.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6885.png)
# [0.6862521171569824, 0.6972752412160238, 0.68466188510259, 0.6917145252227783, 0.6924185951550802]
# saving index 1
# (thread-0) processing	- file IMG_6882.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6882.png)
# [0.6165153582890829, 0.6177414258321127, 0.6098559498786926, 0.6118688186009725, 0.6062668561935425]
# saving index 1
# (thread-0) processing	- file IMG_6919.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6919.png)
# [0.6697243849436442, 0.6783881982167562, 0.6618382136027018, 0.6742053230603536, 0.6769617994626363]
# saving index 1
# (thread-0) processing	- file IMG_6921.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6921.png)
# [0.677563468615214, 0.6886504292488098, 0.6816669305165609, 0.6847789088884989, 0.68403693040212]
# saving index 1
# (thread-0) processing	- file IMG_6920.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6920.png)
# [0.6836848258972168, 0.6871714393297831, 0.6672755082448324, 0.6697221597035726, 0.6649012366930643]
# saving index 1
# (thread-0) processing	- file IMG_6922.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6922.png)
# [0.6869992812474569, 0.7005524635314941, 0.702402134736379, 0.7051345507303873, 0.7026334802309672]
# saving index 3
# (thread-0) processing	- file IMG_6917.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6917.png)
# [0.6627864638964335, 0.6792251467704773, 0.685459315776825, 0.6879119277000427, 0.6913824677467346]
# saving index 4
# (thread-0) processing	- file IMG_6916.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6916.png)
# [0.6486708919207255, 0.6662177244822184, 0.6771929860115051, 0.6818598310152689, 0.6828471024831136]
# saving index 4
# (thread-0) processing	- file IMG_6913.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6913.png)
# [0.6863730351130167, 0.6953091621398926, 0.7073706785837809, 0.7001438736915588, 0.7033466100692749]
# saving index 2
# (thread-0) processing	- file IMG_6914.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6914.png)
# [0.6911827325820923, 0.7042173544565836, 0.6996878186861674, 0.6991023818651835, 0.6961354613304138]
# saving index 1
# (thread-0) processing	- file IMG_6908.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6908.png)
# [0.6928055087725321, 0.7057633399963379, 0.7093099355697632, 0.7130406300226847, 0.7103315989176432]
# saving index 3
# (thread-0) processing	- file IMG_6915.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6915.png)
# [0.6733111540476481, 0.6796295841534933, 0.686235507329305, 0.6813245415687561, 0.6824337840080261]
# saving index 2
# (thread-0) processing	- file IMG_6909.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6909.png)
# [0.6781041224797567, 0.6955756743748983, 0.7031649748484293, 0.7081122795740763, 0.7077846924463908]
# saving index 3
# (thread-0) processing	- file IMG_6912.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6912.png)
# [0.6897595127423605, 0.6975036064783732, 0.7015204628308614, 0.6950916449228922, 0.6922977566719055]
# saving index 2
# (thread-0) processing	- file IMG_6910.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6910.png)
# [0.6868192950884501, 0.6963258186976115, 0.6850004196166992, 0.6874100168546041, 0.6830069224039713]
# saving index 1
# (thread-0) processing	- file IMG_6907.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6907.png)
# [0.677460253238678, 0.6945351163546244, 0.6950212915738424, 0.7002010941505432, 0.6999339461326599]
# saving index 3
# (thread-0) processing	- file IMG_6905.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6905.png)
# [0.6935927073160807, 0.7035048206647238, 0.6939493219057719, 0.6957143346468607, 0.6925610899925232]
# saving index 1
# (thread-0) processing	- file IMG_6906.png (full path: /content/drive/MyDrive/dataset-creation/treeflowers/raw-10241024/IMG_6906.png)
# Traceback (most recent call last):
#   File "lpips-improve-scale.py", line 225, in <module>
#     main()
#   File "lpips-improve-scale.py", line 220, in main
#     while (not q.empty()):
#   File "/usr/lib/python3.7/queue.py", line 107, in empty
# KeyboardInterrupt
